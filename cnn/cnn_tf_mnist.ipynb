# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
import pandas as pd
import urllib3

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
tf.test.gpu_device_name()

# %% [markdown]
# ## Load Data

# %%
root_folder = '~/Downloads/data/'
root_folder = 'D:/dev/data/'

# %% [markdown]
# #### MNIST

# %%
def get_mnist_data(file_name, split_train_test=False):
    df = pd.read_csv(file_name)
    data = df.as_matrix()
    Y = data[:, 0]
    X = data[:, 1:]

    X = (X - X.mean(axis=1, keepdims=True)) / X.std(axis=1, keepdims=True)


    if split_train_test:
        X, Y = shuffle(X, Y)
        X_train, Y_train = X[:-1000], Y[:-1000]
        X_test, Y_test = X[-1000:], Y[-1000:]
        return X_train, Y_train, X_test, Y_test

    return X, Y

# %%
mnist_folder = root_folder+'mnist/train.csv'
print(mnist_folder)
# Out:
# D:/dev/data/mnist/train.csv

# %%
X_train, Y_train, X_test, Y_test = get_mnist_data(file_name=mnist_folder, split_train_test=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c1a3e6c43e5d> in <module>()
# ----> 1 X_train, Y_train, X_test, Y_test = get_mnist_data(file_name=mnist_folder, split_train_test=True)
#
# <ipython-input-13-6291aa5a9190> in get_mnist_data(file_name, split_train_test)
#       1 def get_mnist_data(file_name, split_train_test=False):
# ----> 2     df = pd.read_csv(file_name)
#       3     data = df.as_matrix()
#       4     Y = data[:, 0]
#       5     X = data[:, 1:]
#
# ...
